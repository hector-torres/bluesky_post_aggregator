# %% [markdown]
# # Author Feed Extractor
#
# This notebook extracts posts from reputable news feeds using Bluesky's API.

# %%
import time
import dotenv
import pandas as pd
import requests
import os
from bs4 import BeautifulSoup

# %% [markdown]
# This cell looks for an existing file containing Bluesky posts, and if one exists, looks loads UUIDs to prevent adding duplicate posts; if file does not exist, it creates it.

# %%
# Step 1: Set paths and filenames
output_dir = 'data/output/1_author_feed_extractor'
output_file = f'collected_feeds.csv'
full_path = os.path.join(output_dir, output_file)

# Step 2: Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Step 3: If file exists, load it and get existing UUIDs
if os.path.exists(full_path):
    existing_df = pd.read_csv(full_path)
    existing_uuids = set(existing_df['uuid'].dropna().unique())
else:
    existing_uuids = pd.DataFrame
    existing_df = pd.DataFrame

# %%
# Load environment variables from .env file
dotenv.load_dotenv('data/input/.env')

# Access environment variables
bluesky_account = os.getenv('BLUESKY_HANDLE')
bluesky_account_password = os.getenv('BLUESKY_APP_PASSWORD')

accounts = [
    "nytimes.com",
    "washingtonpost.com",
    "wsj.com",
    "cnn.com",
    "nbcnews.com",
    "cbsnews.com",
    "latimes.com",
    "expressnews.com",
    "apnews.com",
    "reuters.com",
    "npr.org",
    "msnbc.com",
    "financialtimes.com",
    "bloomberg.com",
    "theguardian.com",
    "chicagotribune.com",
    "usatoday.com",
    "cnbc.com",
    # "bbc.com",
    "axios.com",
    "thehill.com",
    "politico.com",
    "financialtimes.com",
    "economist.com",
    'thediplomat.com',
    'asia.nikkei.com',
    'scmp.com',
    'japantimes.co.jp',
    'aljazeera.com',
    'theguardian.com',
    'politico.eu',
    'sydmorningherald.bsky.social'
]

# %% [markdown]
# This cell handles authentication.

# %%
auth_resp = requests.post(
    "https://bsky.social/xrpc/com.atproto.server.createSession",
    json={"identifier": bluesky_account, "password": bluesky_account_password}
)
auth_resp.raise_for_status()
access_jwt = auth_resp.json()["accessJwt"]

headers = {"Authorization": f"Bearer {access_jwt}"}

# %% [markdown]
# This cell fetches an author's feed

# %%
def fetch_author_feed(actor, cursor=None, limit=10):
    """Fetch posts for the given author handle, with optional pagination cursor."""
    url = "https://bsky.social/xrpc/app.bsky.feed.getAuthorFeed"
    params = {"actor": actor, "limit": limit}
    # if cursor:
    #     params["cursor"] = cursor
    resp = requests.get(url, headers=headers, params=params)
    if resp.status_code == 429:
        # Rate limited; wait and retry
        print("Too many requests, retrying in 5 seconds...")
        time.sleep(5)
        # return fetch_author_feed(actor, cursor, limit)
        return fetch_author_feed(actor, limit)
    resp.raise_for_status()
    return resp.json()

# %% [markdown]
# The following cells begin the monitoring loop.

# %%
collected_posts = []

try:
    for acct in accounts:
        try:
            data = fetch_author_feed(acct, limit=10)
            posts = data.get("feed", [])
            for item in posts:
                post = item.get("post", {})
                record = post.get("record", {})
                author_info = post.get("author", {})

                if record.get("$type") == "app.bsky.feed.post":
                    uuid = post.get("uri", "")
                    text = record.get("text", "").strip()
                    timestamp = record.get("createdAt", "")
                    display_name = author_info.get("displayName", "")
                    title = record.get("embed", {}).get("external", {}).get("title", "")
                    external_uri = record.get("embed", {}).get("external", {}).get("uri", "")

                    if text and timestamp and external_uri:
                        collected_posts.append({
                            "uuid": uuid,
                            "author": acct,
                            "displayName": display_name,
                            "title": title,
                            "text": text,
                            "timestamp": timestamp,
                            "uri": external_uri,
                        })
                    else:
                        collected_posts.append({
                        "uuid": uuid,
                        "author": acct,
                        "displayName": display_name,
                        "title": title,
                        "text": text,
                        "timestamp": timestamp,
                        "uri": '',
                            })
            time.sleep(1)
        except Exception as e:
            print(f"Error fetching feed for {acct}: {e}")
    print(f"\nCollected {len(collected_posts)} posts total.")
except KeyboardInterrupt:
    print("Stopping feed monitor.")
# Out:
# Collected 300 posts total.

# %%
len(collected_posts)
# Out:
# 300

# %% [markdown]
# The cell below searches for UUIDs that already exist in our collection (if any) and discards any newly collected posts that contain the same UUIDs.

# %%
# Convert to DataFrame
raw_df = pd.DataFrame(collected_posts)
# Drop duplicates based on UUID
raw_df = raw_df.drop_duplicates(subset='uuid')

# Filter new data to only include unseen UUIDs
new_df = raw_df[~raw_df['uuid'].isin(existing_uuids)]

new_df
# Out:
#                                                   uuid  \
# 0    at://did:plc:eclio37ymobqex2ncko63h4r/app.bsky...
# 1    at://did:plc:eclio37ymobqex2ncko63h4r/app.bsky...
# 2    at://did:plc:eclio37ymobqex2ncko63h4r/app.bsky...
# 3    at://did:plc:eclio37ymobqex2ncko63h4r/app.bsky...
# 4    at://did:plc:eclio37ymobqex2ncko63h4r/app.bsky...
# ..                                                 ...
# 286  at://did:plc:bak7f4b3jsiqlpyo6o4ejaji/app.bsky...
# 287  at://did:plc:bak7f4b3jsiqlpyo6o4ejaji/app.bsky...
# 288  at://did:plc:e5ixzv36nmsa5brpxw5tqixg/app.bsky...
# 289  at://did:plc:kquml2hoj6p7qsw7ohlgfa5k/app.bsky...
# 290  at://did:plc:4ero2n7xswsmqcvonfgza3ol/app.bsky...
#
#                            author            displayName  \
# 0                     nytimes.com     The New York Times
# 1                     nytimes.com     The New York Times
# 2                     nytimes.com     The New York Times
# 3                     nytimes.com     The New York Times
# 4                     nytimes.com     The New York Times
# ..                            ...                    ...
# 286                   politico.eu        POLITICO Europe
# 287                   politico.eu        POLITICO Europe
# 288                   politico.eu           Camille Gijs
# 289                   politico.eu           Pieter Haeck
# 290  sydmorningherald.bsky.social  Sydney Morning Herald
#
#                                                  title  \
# 0    Japan Welcomes a New Sumo Champ. Surprise: He’...
# 1
# 2
# 3    Do I Need to Refrigerate Ketchup? An A-to-Z Gu...
# 4
# ..                                                 ...
# 286  Christine Lagarde discussed leaving ECB early ...
# 287  Prague accuses China of hacking Czech foreign ...
# 288  A big, beautiful EU trade deal with Trump? Dre...
# 289  US Republicans slam EU ‘double standard’ over ...
# 290  Coalition finally back together as Littleproud...
#
#                                                   text  \
# 0    Onosato Daiki of Japan was named on Wednesday ...
# 1    From @theathleticfc.bsky.social: Lamine Yamal ...
# 2    The mere thought of ticks makes our skin crawl...
# 3    Do you need to refrigerate ketchup? Soy sauce?...
# 4    How did you do in Connections today? Players m...
# ..                                                 ...
# 286  Christine Lagarde has discussed leaving the Eu...
# 287  Prague accuses China of hacking Czech foreign ...
# 288  Donald Trump may be happy with the EU’s promis...
# 289  NEW: U.S. Republican lawmakers are reproaching...
# 290  The Coalition is officially back together afte...
#
#                     timestamp  \
# 0    2025-05-28T15:18:52.783Z
# 1    2025-05-28T15:12:48.960Z
# 2    2025-05-28T14:38:26.326Z
# 3    2025-05-28T14:32:38.171Z
# 4    2025-05-28T14:29:10.910Z
# ..                        ...
# 286  2025-05-28T10:30:36.896Z
# 287  2025-05-28T09:25:35.827Z
# 288  2025-05-28T09:15:42.803Z
# 289  2025-05-28T07:02:24.127Z
# 290  2025-05-28T02:35:10.348Z
#
#                                                    uri
# 0    https://www.nytimes.com/2025/05/28/world/asia/...
# 1
# 2
# 3                              https://nyti.ms/43udGJj
# 4
# ..                                                 ...
# 286                          https://ow.ly/NxCk50VZVXE
# 287                          https://ow.ly/3IQ250VZTO6
# 288  https://www.politico.eu/article/eu-trade-deal-...
# 289  https://www.politico.eu/article/us-republicans...
# 290  https://www.smh.com.au/politics/federal/coalit...
#
# [220 rows x 7 columns]

# %%
# Convert timestamp to datetime and sort
new_df['timestamp'] = pd.to_datetime(new_df['timestamp'], utc=True, errors='coerce')
new_df = new_df.sort_values(by='timestamp', ascending=False)

# Desired column order
cols = ['title', 'text'] + [col for col in new_df.columns if col not in ['title', 'text', 'uuid']] + ['uuid']
# Reorder the DataFrame
new_df = new_df[cols]
# Rename the 'uri' column
new_df = new_df.rename(columns={'uri': 'external_url'})
# Out:
# /var/folders/p1/8fyq7zs911z9m3y9xhtyw6nh0000gn/T/ipykernel_44248/1457574338.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['timestamp'] = pd.to_datetime(new_df['timestamp'], utc=True, errors='coerce')

# %%
new_df.head()
# Out:
#                                                  title  \
# 50   Capitol police chief Thomas Manger says Trump'...
# 0    Japan Welcomes a New Sumo Champ. Surprise: He’...
# 1
# 110  Hayes: We are more powerful than ‘one petty, a...
# 200  ‘He Is Ohio’: DeWine Pitches an Alternative to...
#
#                                                   text        author  \
# 50   Capitol police chief Thomas Manger has led — a...   cbsnews.com
# 0    Onosato Daiki of Japan was named on Wednesday ...   nytimes.com
# 1    From @theathleticfc.bsky.social: Lamine Yamal ...   nytimes.com
# 110  OPINION:\n\nHayes: We are more powerful than ‘...     msnbc.com
# 200  Column: Ohio Gov. Mike DeWine has a new plan t...  politico.com
#
#             displayName                        timestamp  \
# 50             CBS News 2025-05-28 15:20:01.664000+00:00
# 0    The New York Times 2025-05-28 15:18:52.783000+00:00
# 1    The New York Times 2025-05-28 15:12:48.960000+00:00
# 110               MSNBC 2025-05-28 15:11:37.400000+00:00
# 200            Politico 2025-05-28 15:10:58.986000+00:00
#
#                                           external_url  \
# 50                             https://cbsn.ws/4jou7wO
# 0    https://www.nytimes.com/2025/05/28/world/asia/...
# 1
# 110        https://www.youtube.com/watch?v=W-cCxwxI8Fk
# 200  https://www.politico.com/news/magazine/2025/05...
#
#                                                   uuid
# 50   at://did:plc:3bxtpdpr73tf7tldv5q4oyqc/app.bsky...
# 0    at://did:plc:eclio37ymobqex2ncko63h4r/app.bsky...
# 1    at://did:plc:eclio37ymobqex2ncko63h4r/app.bsky...
# 110  at://did:plc:ofbkqcjzvm6gtwuufsubnkaf/app.bsky...
# 200  at://did:plc:yf6hctt2ug3qyfty4in64yob/app.bsky...

# %% [markdown]
# The following cells fetch additional metadata for each post by accessing embedded links within each post (if available)

# %%
def fetch_metadata(url):
    try:
        headers = {'User-Agent': 'Mozilla/5.0'}
        response = requests.get(url, timeout=10, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Page title
        page_title = soup.title.string.strip() if soup.title else ''

        # Meta description (Open Graph preferred)
        meta = soup.find('meta', attrs={'property': 'og:description'}) or \
               soup.find('meta', attrs={'name': 'description'})
        description = meta['content'].strip() if meta and 'content' in meta.attrs else ''

        return page_title, description

    except Exception as e:
        return '', ''

# %%
if not new_df.empty:
    new_df[['page_title', 'meta_description']] = new_df['external_url'].apply(
        lambda url: pd.Series(fetch_metadata(url)))

# %% [markdown]
# This cell saves collected posts to file.

# %%
df = pd.concat([existing_df, new_df], ignore_index=True)

df.to_csv(full_path, index=False)

print(f"Appended {len(new_df)} new rows.")
# Out:
# Appended 220 new rows.
# Final saved file: data/output/1_author_feed_extractor/collected_feeds.csv (total 280 rows)

# %%
df.sort_index(ascending=False)
# Out:
#                                                  title  \
# 529  Aboriginal man, 24, dies in police custody in ...
# 528  Gulf states, China take centre stage at summit...
# 527  Ukraine’s Zelenskyy to meet Germany’s Merz in ...
# 526  German court rejects Peruvian farmer’s climate...
# 525  US pauses new student visas: What it means and...
# ..                                                 ...
# 4    Former Times reporter sues Villanueva, L.A Cou...
# 3    Trump touts free "Golden Dome" for Canada, as ...
# 2    SpaceX megarocket gets farther in test than la...
# 1    New student visas paused as State Dept. plans ...
# 0    Miley Cyrus says she has Reinke's edema, a dis...
#
#                                                   text              author  \
# 529  NT police say ‘the man stopped breathing’ shor...       aljazeera.com
# 528  The GCC, China, ASEAN countries pledged to pro...       aljazeera.com
# 527  Talks come after German chancellor says allies...       aljazeera.com
# 526  Judge rules that companies ‘may be obligated t...       aljazeera.com
# 525  The Trump administration has paused new visa i...       aljazeera.com
# ..                                                 ...                 ...
# 4    Former Times reporter sues Villanueva, L.A Cou...         latimes.com
# 3    Canadian PM Mark Carney told CBC today he want...           axios.com
# 2    UPDATE: SpaceX's Starship travels farther in i...             cnn.com
# 1    The State Department on Tuesday suspended fore...  washingtonpost.com
# 0    Miley Cyrus has opened up about her experience...         cbsnews.com
#
#              displayName                         timestamp  \
# 529                                                    NaT
# 528                                                    NaT
# 527                                                    NaT
# 526                                                    NaT
# 525                                                    NaT
# ..                   ...                               ...
# 4      Los Angeles Times  2025-05-28 00:51:03.498000+00:00
# 3                  Axios  2025-05-28 00:51:43.197000+00:00
# 2                    CNN  2025-05-28 00:52:04.026000+00:00
# 1    The Washington Post  2025-05-28 00:52:20.780000+00:00
# 0               CBS News  2025-05-28 01:00:00.970000+00:00
#
#                                           external_url  \
# 529                             https://bit.ly/3HrRxE2
# 528                             https://bit.ly/3HeFOZG
# 527                             https://bit.ly/4mBTTAw
# 526                             https://bit.ly/43zznrE
# 525                             https://bit.ly/4kHmany
# ..                                                 ...
# 4    https://www.latimes.com/california/story/2025-...
# 3    https://www.axios.com/2025/05/28/trump-canada-...
# 2    https://www.cnn.com/science/live-news/spacex-s...
# 1    https://www.washingtonpost.com/education/2025/...
# 0                              https://cbsn.ws/43zE5p6
#
#                                                   uuid  \
# 529  at://did:plc:2lofqead276vtc5647ye7sl2/app.bsky...
# 528  at://did:plc:2lofqead276vtc5647ye7sl2/app.bsky...
# 527  at://did:plc:2lofqead276vtc5647ye7sl2/app.bsky...
# 526  at://did:plc:2lofqead276vtc5647ye7sl2/app.bsky...
# 525  at://did:plc:2lofqead276vtc5647ye7sl2/app.bsky...
# ..                                                 ...
# 4    at://did:plc:d2jith367s6ybc3ldsusgdae/app.bsky...
# 3    at://did:plc:f6avy7jkujdhusski5n64joj/app.bsky...
# 2    at://did:plc:dzezcmpb3fhcpns4n4xm4ur5/app.bsky...
# 1    at://did:plc:k5nskatzhyxersjilvtnz4lh/app.bsky...
# 0    at://did:plc:3bxtpdpr73tf7tldv5q4oyqc/app.bsky...
#
#                                             page_title  \
# 529  Aboriginal man, 24, dies in police custody in ...
# 528  Gulf states, China take centre stage at summit...
# 527  Merz says Germany will help Ukraine produce lo...
# 526  German court rejects Peruvian farmer’s climate...
# 525  US pauses new student visas: What it means and...
# ..                                                 ...
# 4    Former Times reporter sues Villanueva, L.A Cou...
# 3                                                  NaN
# 2    SpaceX launches Starship test flight 9: Live u...
# 1                                                  NaN
# 0    Miley Cyrus says she has Reinke's edema, a dis...
#
#                                       meta_description
# 529  NT police say ‘the man stopped breathing’ shor...
# 528  The GCC, China, ASEAN countries pledged to pro...
# 527  Zelenskyy said the two leaders agreed to coope...
# 526  Judge rules that companies ‘may be obligated t...
# 525  The Trump administration has paused new visa i...
# ..                                                 ...
# 4    Former Times reporter Maya Lau has filed a law...
# 3                                                  NaN
# 2    SpaceX has launched a ninth uncrewed test flig...
# 1                                                  NaN
# 0    Miley Cyrus has opened up about her experience...
#
# [530 rows x 9 columns]
